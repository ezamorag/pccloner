# %%
import pynput 

def normalize(event):
    if not isinstance(event[0], tuple):
        return normalize(((event[0],), event[1]))
    key, is_pressed = event
    return (
        tuple(
            pynput.keyboard.KeyCode.from_char(key)
            if isinstance(key, six.string_types)
            else key.value if key in pynput.keyboard.Key
            else key
            for key in event[0]),
        is_pressed)

def on_press(key):
    print('pressed', key)

def on_release(key):
    print('released', key)

listener = pynput.keyboard.Listener(on_press=on_press, on_release=on_release)
listener.start()
# Out:
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# released Key.enter
# pressed Key.ctrl
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# pressed 'z'
# released 'z'
# released Key.ctrl
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# released Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# released Key.enter
# pressed Key.ctrl
# released Key.ctrl
# pressed Key.ctrl
# released Key.ctrl
# pressed Key.ctrl_r
# released Key.ctrl_r
# pressed Key.ctrl_r
# released Key.ctrl_r
# pressed Key.ctrl_r
# released Key.ctrl_r
# pressed Key.shift_r
# released Key.shift_r
# pressed Key.caps_lock
# released Key.caps_lock
# pressed Key.caps_lock
# released Key.caps_lock
# pressed Key.caps_lock
# released Key.caps_lock
# pressed Key.caps_lock
# released Key.caps_lock
# pressed 'f'
# released 'f'
# pressed 'f'
# released 'f'
# pressed 'f'
# released 'f'
# pressed Key.shift_r
# released Key.shift_r
# pressed Key.shift_r
# pressed 'F'
# pressed 'F'
# pressed 'F'
# released Key.shift_r
# pressed 'f'
# pressed 'f'
# released 'f'
# pressed 't'
# released 't'
# pressed 'e'
# released 'e'
# pressed 'c'
# released 'c'
# pressed 'l'
# released 'l'
# pressed Key.backspace
# released Key.backspace
# pressed 'l'
# released 'l'
# pressed 'a'
# released 'a'
# pressed 's'
# released 's'
# pressed Key.space
# released Key.space
# pressed 'e'
# released 'e'
# pressed 's'
# pressed 'p'
# released 's'
# released 'p'
# pressed 'e'
# released 'e'
# pressed 'c'
# pressed 'i'
# released 'i'
# released 'c'
# pressed 'a'
# pressed 'l'
# released 'a'
# released 'l'
# pressed 'e'
# released 'e'
# pressed 's'
# released 's'
# pressed Key.enter
# released Key.enter
# pressed 'd'
# released 'd'
# pressed 'f'
# released 'f'
# pressed Key.ctrl
# released Key.ctrl
# pressed Key.cmd
# released Key.cmd
# pressed Key.ctrl_r
# released Key.ctrl_r
# pressed Key.shift
# released Key.shift
# pressed Key.shift_r
# released Key.shift_r
# pressed Key.shift_r
# released Key.shift_r
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# released Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# pressed Key.tab
# released Key.tab
# pressed Key.enter
# pressed Key.enter
# pressed Key.enter
# released Key.enter
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# pressed Key.backspace
# pressed Key.backspace
# pressed Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed <65027>
# released <65027>
# pressed <65027>
# released <65027>
# pressed '2'
# released '2'
# pressed '2'
# released '2'
# pressed '2'
# released '2'
# pressed '2'
# released '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# released '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# pressed '2'
# released '2'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# pressed 'u'
# released 'u'
# pressed Key.ctrl
# released Key.ctrl
# pressed Key.media_play_pause
# released Key.media_play_pause
# pressed Key.media_play_pause
# released Key.media_play_pause
# pressed 'r'
# released 'r'
# pressed 'e'
# released 'e'
# pressed 't'
# released 't'
# pressed 'u'
# released 'u'
# pressed 'r'
# released 'r'
# pressed 'n'
# released 'n'
# pressed Key.space
# released Key.space
# pressed 'c'
# released 'c'
# pressed 'e'
# released 'e'
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed 'd'
# released 'd'
# pressed 'e'
# released 'e'
# pressed 'l'
# released 'l'
# pressed 'e'
# released 'e'
# pressed 't'
# released 't'
# pressed 'e'
# released 'e'
# pressed Key.space
# released Key.space
# pressed 'c'
# released 'c'
# pressed 'e'
# released 'e'
# pressed 'l'
# released 'l'
# pressed 'l'
# released 'l'
# pressed Key.space
# released Key.space
# pressed 'i'
# released 'i'
# pressed 'n'
# released 'n'
# pressed Key.space
# released Key.space
# pressed 'v'
# released 'v'
# pressed 's'
# released 's'
# pressed 'c'
# released 'c'
# pressed Key.enter
# released Key.enter
# pressed 'w'
# released 'w'
# pressed 'r'
# pressed 'i'
# released 'r'
# released 'i'
# pressed 't'
# released 't'
# pressed 'e'
# released 'e'
# pressed Key.space
# released Key.space
# pressed 'r'
# released 'r'
# pressed 'e'
# released 'e'
# pressed 'v'
# released 'v'
# pressed 'e'
# released 'e'
# pressed 'r'
# released 'r'
# pressed 's'
# released 's'
# pressed 'e'
# released 'e'
# pressed Key.space
# released Key.space
# pressed 's'
# released 's'
# pressed 'l'
# released 'l'
# pressed 'a'
# released 'a'
# pressed 's'
# released 's'
# pressed 'h'
# released 'h'
# pressed Key.space
# released Key.space
# pressed 'i'
# released 'i'
# pressed 'n'
# released 'n'
# pressed Key.space
# released Key.space
# pressed 's'
# released 's'
# pressed 't'
# released 't'
# pressed 'r'
# released 'r'
# pressed 'i'
# released 'i'
# pressed 'n'
# released 'n'
# pressed 'g'
# released 'g'
# pressed Key.space
# released Key.space
# pressed 'p'
# released 'p'
# pressed 'y'
# released 'y'
# pressed 't'
# released 't'
# pressed 'o'
# pressed 'h'
# released 'o'
# released 'h'
# pressed 'n'
# released 'n'
# pressed Key.enter
# released Key.enter
# pressed 's'
# released 's'
# pressed 'a'
# released 'a'
# pressed 'v'
# released 'v'
# pressed 'e'
# released 'e'
# pressed Key.space
# released Key.space
# pressed 'd'
# released 'd'
# pressed 'i'
# released 'i'
# pressed 'c'
# released 'c'
# pressed 't'
# pressed 'i'
# released 't'
# released 'i'
# pressed 'o'
# released 'o'
# pressed 'n'
# released 'n'
# pressed 'a'
# released 'a'
# pressed 'r'
# released 'r'
# pressed 'y'
# released 'y'
# pressed Key.space
# released Key.space
# pressed 'i'
# released 'i'
# pressed 'n'
# released 'n'
# pressed Key.space
# released Key.space
# pressed 't'
# released 't'
# pressed 'e'
# released 'e'
# pressed 'x'
# released 'x'
# pressed 't'
# released 't'
# pressed Key.enter
# released Key.enter
# pressed 'p'
# released 'p'
# pressed 'y'
# released 'y'
# pressed 'n'
# released 'n'
# pressed 'p'
# released 'p'
# pressed 'u'
# released 'u'
# pressed 't'
# released 't'
# pressed Key.space
# released Key.space
# pressed 'k'
# released 'k'
# pressed 'e'
# released 'e'
# pressed 'y'
# released 'y'
# pressed Key.space
# released Key.space
# pressed 'f'
# released 'f'
# pressed 'n'
# released 'n'
# pressed Key.enter
# released Key.enter
# pressed 'k'
# released 'k'
# pressed 'e'
# released 'e'
# pressed 'y'
# released 'y'
# pressed 'c'
# released 'c'
# pressed 'o'
# released 'o'
# pressed 'd'
# released 'd'
# pressed 'e'
# released 'e'
# pressed Key.space
# released Key.space
# pressed 'p'
# released 'p'
# pressed 'y'
# released 'y'
# pressed 'n'
# released 'n'
# pressed 'p'
# released 'p'
# pressed 'u'
# released 'u'
# pressed 't'
# released 't'
# pressed Key.ctrl
# pressed 'c'
# released 'c'
# released Key.ctrl
# pressed Key.ctrl
# pressed 'v'
# released 'v'
# released Key.ctrl
# pressed '¿'
# released '¿'
# pressed '¿'
# released '¿'
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace
# pressed Key.backspace
# released Key.backspace

# %%
listener.stop()

# %%
from pynput.keyboard import Key, Controller
import time 

kController = Controller()

for k in Key.__dict__['_member_map_'].keys(): 
    print('here', k)
    kController.press(Key.__dict__[k])
    kController.release(Key.__dict__[k])
    time.sleep(0.5)

# %%
kController.press(Key.space)
kController.release(Key.space)
time.sleep(0.5)
kController.press('a')
kController.release('a')

# %%
from pynput.keyboard import Key

for k in Key.__dict__.keys():
    print(k)
    print(Key.__dict__[k])
    print()

print(len(Key.__dict__['_value2member_map_']), 
      len(Key.__dict__['_member_names_']),
      len(Key.__dict__['_member_map_']), 
      len(Key.__dict__)-8)
# Out:
# _generate_next_value_
# <function Enum._generate_next_value_ at 0x7f247d37bb50>
#
# __module__
# pynput.keyboard._xorg
#
# __doc__
# An enumeration.
#
# _member_names_
# ['alt', 'alt_r', 'alt_gr', 'backspace', 'caps_lock', 'cmd', 'cmd_r', 'ctrl', 'ctrl_r', 'delete', 'down', 'end', 'enter', 'esc', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9', 'f10', 'f11', 'f12', 'f13', 'f14', 'f15', 'f16', 'f17', 'f18', 'f19', 'f20', 'home', 'left', 'page_down', 'page_up', 'right', 'shift', 'shift_r', 'space', 'tab', 'up', 'media_play_pause', 'media_volume_mute', 'media_volume_down', 'media_volume_up', 'media_previous', 'media_next', 'insert', 'menu', 'num_lock', 'pause', 'print_screen', 'scroll_lock']
#
# _member_map_
# {'alt': <Key.alt: <65513>>, 'alt_l': <Key.alt: <65513>>, 'alt_r': <Key.alt_r: <65514>>, 'alt_gr': <Key.alt_gr: <65406>>, 'backspace': <Key.backspace: <65288>>, 'caps_lock': <Key.caps_lock: <65509>>, 'cmd': <Key.cmd: <65515>>, 'cmd_l': <Key.cmd: <65515>>, 'cmd_r': <Key.cmd_r: <65516>>, 'ctrl': <Key.ctrl: <65507>>, 'ctrl_l': <Key.ctrl: <65507>>, 'ctrl_r': <Key.ctrl_r: <65508>>, 'delete': <Key.delete: <65535>>, 'down': <Key.down: <65364>>, 'end': <Key.end: <65367>>, 'enter': <Key.enter: <65293>>, 'esc': <Key.esc: <65307>>, 'f1': <Key.f1: <65470>>, 'f2': <Key.f2: <65471>>, 'f3': <Key.f3: <65472>>, 'f4': <Key.f4: <65473>>, 'f5': <Key.f5: <65474>>, 'f6': <Key.f6: <65475>>, 'f7': <Key.f7: <65476>>, 'f8': <Key.f8: <65477>>, 'f9': <Key.f9: <65478>>, 'f10': <Key.f10: <65479>>, 'f11': <Key.f11: <65480>>, 'f12': <Key.f12: <65481>>, 'f13': <Key.f13: <65482>>, 'f14': <Key.f14: <65483>>, 'f15': <Key.f15: <65484>>, 'f16': <Key.f16: <65485>>, 'f17': <Key.f17: <65486>>, 'f18': <Key.f18: <65487>>, 'f19': <Key.f19: <65488>>, 'f20': <Key.f20: <65489>>, 'home': <Key.home: <65360>>, 'left': <Key.left: <65361>>, 'page_down': <Key.page_down: <65366>>, 'page_up': <Key.page_up: <65365>>, 'right': <Key.right: <65363>>, 'shift': <Key.shift: <65505>>, 'shift_l': <Key.shift: <65505>>, 'shift_r': <Key.shift_r: <65506>>, 'space': <Key.space: ' '>, 'tab': <Key.tab: <65289>>, 'up': <Key.up: <65362>>, 'media_play_pause': <Key.media_play_pause: <269025044>>, 'media_volume_mute': <Key.media_volume_mute: <269025042>>, 'media_volume_down': <Key.media_volume_down: <269025041>>, 'media_volume_up': <Key.media_volume_up: <269025043>>, 'media_previous': <Key.media_previous: <269025046>>, 'media_next': <Key.media_next: <269025047>>, 'insert': <Key.insert: <65379>>, 'menu': <Key.menu: <65383>>, 'num_lock': <Key.num_lock: <65407>>, 'pause': <Key.pause: <65299>>, 'print_screen': <Key.print_screen: <65377>>, 'scroll_lock': <Key.scroll_lock: <65300>>}
#
# _member_type_
# <class 'object'>
#
# _value2member_map_
# {<65513>: <Key.alt: <65513>>, <65514>: <Key.alt_r: <65514>>, <65406>: <Key.alt_gr: <65406>>, <65288>: <Key.backspace: <65288>>, <65509>: <Key.caps_lock: <65509>>, <65515>: <Key.cmd: <65515>>, <65516>: <Key.cmd_r: <65516>>, <65507>: <Key.ctrl: <65507>>, <65508>: <Key.ctrl_r: <65508>>, <65535>: <Key.delete: <65535>>, <65364>: <Key.down: <65364>>, <65367>: <Key.end: <65367>>, <65293>: <Key.enter: <65293>>, <65307>: <Key.esc: <65307>>, <65470>: <Key.f1: <65470>>, <65471>: <Key.f2: <65471>>, <65472>: <Key.f3: <65472>>, <65473>: <Key.f4: <65473>>, <65474>: <Key.f5: <65474>>, <65475>: <Key.f6: <65475>>, <65476>: <Key.f7: <65476>>, <65477>: <Key.f8: <65477>>, <65478>: <Key.f9: <65478>>, <65479>: <Key.f10: <65479>>, <65480>: <Key.f11: <65480>>, <65481>: <Key.f12: <65481>>, <65482>: <Key.f13: <65482>>, <65483>: <Key.f14: <65483>>, <65484>: <Key.f15: <65484>>, <65485>: <Key.f16: <65485>>, <65486>: <Key.f17: <65486>>, <65487>: <Key.f18: <65487>>, <65488>: <Key.f19: <65488>>, <65489>: <Key.f20: <65489>>, <65360>: <Key.home: <65360>>, <65361>: <Key.left: <65361>>, <65366>: <Key.page_down: <65366>>, <65365>: <Key.page_up: <65365>>, <65363>: <Key.right: <65363>>, <65505>: <Key.shift: <65505>>, <65506>: <Key.shift_r: <65506>>, ' ': <Key.space: ' '>, <65289>: <Key.tab: <65289>>, <65362>: <Key.up: <65362>>, <269025044>: <Key.media_play_pause: <269025044>>, <269025042>: <Key.media_volume_mute: <269025042>>, <269025041>: <Key.media_volume_down: <269025041>>, <269025043>: <Key.media_volume_up: <269025043>>, <269025046>: <Key.media_previous: <269025046>>, <269025047>: <Key.media_next: <269025047>>, <65379>: <Key.insert: <65379>>, <65383>: <Key.menu: <65383>>, <65407>: <Key.num_lock: <65407>>, <65299>: <Key.pause: <65299>>, <65377>: <Key.print_screen: <65377>>, <65300>: <Key.scroll_lock: <65300>>}
#
# alt
# Key.alt
#
# alt_l
# Key.alt
#
# alt_r
# Key.alt_r
#
# alt_gr
# Key.alt_gr
#
# backspace
# Key.backspace
#
# caps_lock
# Key.caps_lock
#
# cmd
# Key.cmd
#
# cmd_l
# Key.cmd
#
# cmd_r
# Key.cmd_r
#
# ctrl
# Key.ctrl
#
# ctrl_l
# Key.ctrl
#
# ctrl_r
# Key.ctrl_r
#
# delete
# Key.delete
#
# down
# Key.down
#
# end
# Key.end
#
# enter
# Key.enter
#
# esc
# Key.esc
#
# f1
# Key.f1
#
# f2
# Key.f2
#
# f3
# Key.f3
#
# f4
# Key.f4
#
# f5
# Key.f5
#
# f6
# Key.f6
#
# f7
# Key.f7
#
# f8
# Key.f8
#
# f9
# Key.f9
#
# f10
# Key.f10
#
# f11
# Key.f11
#
# f12
# Key.f12
#
# f13
# Key.f13
#
# f14
# Key.f14
#
# f15
# Key.f15
#
# f16
# Key.f16
#
# f17
# Key.f17
#
# f18
# Key.f18
#
# f19
# Key.f19
#
# f20
# Key.f20
#
# home
# Key.home
#
# left
# Key.left
#
# page_down
# Key.page_down
#
# page_up
# Key.page_up
#
# right
# Key.right
#
# shift
# Key.shift
#
# shift_l
# Key.shift
#
# shift_r
# Key.shift_r
#
# space
# Key.space
#
# tab
# Key.tab
#
# up
# Key.up
#
# media_play_pause
# Key.media_play_pause
#
# media_volume_mute
# Key.media_volume_mute
#
# media_volume_down
# Key.media_volume_down
#
# media_volume_up
# Key.media_volume_up
#
# media_previous
# Key.media_previous
#
# media_next
# Key.media_next
#
# insert
# Key.insert
#
# menu
# Key.menu
#
# num_lock
# Key.num_lock
#
# pause
# Key.pause
#
# print_screen
# Key.print_screen
#
# scroll_lock
# Key.scroll_lock
#
# __new__
# <function Enum.__new__ at 0x7f247d37bac0>
#
# 56 56 60 60
