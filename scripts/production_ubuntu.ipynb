# %%
import os, re
import subprocess

def run_command(command):
    """Runs a shell command and prints the output."""
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    output, error = process.communicate()
    if output:
        print(output.decode())
    if error:
        print(error.decode())

def getversion():
    with open("setup.py", "r") as f:
        content = f.read()
    match = re.search(r"version='([^']+)'", content)
    if match:
        version = match.group(1)
    else:
        print("Version not found.")
    return version 

def uninstallingpccloner():
    # Run the command, sending 'y\n' (yes + newline) as input
    process = subprocess.Popen("pip uninstall pccloner", shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    output, error = process.communicate(input='y\n') 
    # Print the output and any errors
    print(output)
    if error:
        print(error)
        
# Make sure that yuo have the environment below: 
# conda create --name x python==3.10
# conda activate x
# pip install pyinstaller
# pip install --upgrade build

# %% [markdown]
# ### Routine for producing the pip package and the ubuntu app

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
print('Building ...')
run_command('python -m build')
print('Downloading PIP package ...')
run_command('twine upload --repository pypi dist/*')

print(f'Installing the latest pccloner version {getversion()} ...')
uninstallingpccloner()
run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py -n pccloner_applinux_' + getversion())
run_command('pyinstaller -F scripts/pccollector.py -n pccollector_applinux_' + getversion())
# Out:
# Building ...
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for sdist...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# running check
# creating pccloner-0.1.3
# creating pccloner-0.1.3/src/pccloner
# creating pccloner-0.1.3/src/pccloner.egg-info
# copying files to pccloner-0.1.3...
# copying LICENSE -> pccloner-0.1.3
# copying README.md -> pccloner-0.1.3
# copying pyproject.toml -> pccloner-0.1.3
# copying setup.py -> pccloner-0.1.3
# copying src/pccloner/__init__.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner/pcdata.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner/pctask_pr.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner/pctask_press.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner/ubuntu.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner/win11.py -> pccloner-0.1.3/src/pccloner
# copying src/pccloner.egg-info/PKG-INFO -> pccloner-0.1.3/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.3/src/pccloner.egg-info
# copying src/pccloner.egg-info/dependency_links.txt -> pccloner-0.1.3/src/pccloner.egg-info
# copying src/pccloner.egg-info/requires.txt -> pccloner-0.1.3/src/pccloner.egg-info
# copying src/pccloner.egg-info/top_level.txt -> pccloner-0.1.3/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.3/src/pccloner.egg-info
# Writing pccloner-0.1.3/setup.cfg
# Creating tar archive
# removing 'pccloner-0.1.3' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for wheel...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/pccloner
# copying src/pccloner/__init__.py -> build/lib/pccloner
# copying src/pccloner/pcdata.py -> build/lib/pccloner
# copying src/pccloner/pctask_press.py -> build/lib/pccloner
# copying src/pccloner/pctask_pr.py -> build/lib/pccloner
# copying src/pccloner/win11.py -> build/lib/pccloner
# copying src/pccloner/ubuntu.py -> build/lib/pccloner
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/pccloner
# copying build/lib/pccloner/__init__.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/ubuntu.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/win11.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_pr.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_press.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pcdata.py -> build/bdist.linux-x86_64/wheel/./pccloner
# running install_egg_info
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# Copying src/pccloner.egg-info to build/bdist.linux-x86_64/wheel/./pccloner-0.1.3-py3.10.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/pccloner-0.1.3.dist-info/WHEEL
# creating '/home/ezamorag/GitHub/pccloner/dist/.tmp-fn1znp5k/pccloner-0.1.3-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'pccloner/__init__.py'
# adding 'pccloner/pcdata.py'
# adding 'pccloner/pctask_pr.py'
# adding 'pccloner/pctask_press.py'
# adding 'pccloner/ubuntu.py'
# adding 'pccloner/win11.py'
# adding 'pccloner-0.1.3.dist-info/LICENSE'
# adding 'pccloner-0.1.3.dist-info/METADATA'
# adding 'pccloner-0.1.3.dist-info/WHEEL'
# adding 'pccloner-0.1.3.dist-info/top_level.txt'
# adding 'pccloner-0.1.3.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built pccloner-0.1.3.tar.gz and pccloner-0.1.3-py3-none-any.whl
#
# Downloading PIP package ...
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading pccloner-0.1.2-py3-none-any.whl
# 100%|██████████| 26.4k/26.4k [00:00<00:00, 41.9kB/s]
# Uploading pccloner-0.1.3-py3-none-any.whl
# 100%|██████████| 27.4k/27.4k [00:01<00:00, 17.2kB/s]
# Uploading pccloner-0.1.2.tar.gz
# 100%|██████████| 24.0k/24.0k [00:00<00:00, 137kB/s]
# Uploading pccloner-0.1.3.tar.gz
# 100%|██████████| 25.2k/25.2k [00:00<00:00, 26.7kB/s]
#
# InvalidDistribution: Unknown distribution format: 'pccloner_applinux_0.1.2'
#
# Installing the latest pccloner version 0.1.3 ...
# Found existing installation: pccloner 0.1.2
# Uninstalling pccloner-0.1.2:
#   Would remove:
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner-0.1.2.dist-info/*
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner/*
# Proceed (Y/n)?   Successfully uninstalled pccloner-0.1.2
#
# Collecting pccloner==0.1.3
#   Downloading pccloner-0.1.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pynput>=1.7.6 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.3) (1.7.7)
# Requirement already satisfied: pyautogui>=0.9.54 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.3) (0.9.54)
# Requirement already satisfied: keyboard>=0.13.5 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.3) (0.13.5)
# Requirement already satisfied: pandas>=2.1.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.3) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.3) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.3) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.3) (2024.1)
# Requirement already satisfied: pymsgbox in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (0.0.9)
# Requirement already satisfied: mouseinfo in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (0.1.3)
# Requirement already satisfied: python3-Xlib in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.3) (0.15)
# Requirement already satisfied: six in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.3) (1.16.0)
# Requirement already satisfied: evdev>=1.3 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.3) (1.7.1)
# Requirement already satisfied: python-xlib>=0.17 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.3) (0.33)
# Requirement already satisfied: pyrect in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pygetwindow>=0.0.5->pyautogui>=0.9.54->pccloner==0.1.3) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyscreeze>=0.1.21->pyautogui>=0.9.54->pccloner==0.1.3) (10.4.0)
# Requirement already satisfied: pyperclip in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from mouseinfo->pyautogui>=0.9.54->pccloner==0.1.3) (1.9.0)
# Downloading pccloner-0.1.3-py3-none-any.whl (20 kB)
# Installing collected packages: pccloner
# Successfully installed pccloner-0.1.3
#
# Generating executable for ubuntu ...
# 460 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 460 INFO: Python: 3.10.0 (conda)
# 463 INFO: Platform: Linux-5.15.0-122-generic-x86_64-with-glibc2.31
# 463 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 463 INFO: wrote /home/ezamorag/GitHub/pccloner/pccloner_applinux_0.1.3.spec
# 467 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 673 INFO: checking Analysis
# 674 INFO: Building Analysis because Analysis-00.toc is non existent
# 674 INFO: Running Analysis Analysis-00.toc
# 674 INFO: Target bytecode optimization level: 0
# 674 INFO: Initializing module dependency graph...
# 675 INFO: Caching module graph hooks...
# 698 INFO: Analyzing base_library.zip ...
# 1528 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1579 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2759 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3611 INFO: Caching module dependency graph...
# 3672 INFO: Looking for Python shared library...
# 3690 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3691 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/testing.py
# 3723 INFO: Processing standard module hook 'hook-pynput.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 4223 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 4308 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4411 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4442 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4498 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4912 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4966 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 5226 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5861 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6017 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6063 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6607 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 7408 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 7409 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 8109 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 8116 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 8138 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 8308 INFO: Processing standard module hook 'hook-Xlib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 8842 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 10193 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 10301 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12801 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13607 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 14787 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 15125 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 16998 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 17807 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18208 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19269 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 19855 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 20928 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 20934 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 21151 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 21853 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22726 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23144 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23338 INFO: Processing module hooks (post-graph stage)...
# 23814 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23841 WARNING: Hidden import "jinja2" not found!
# 24185 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 24186 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 25801 INFO: Performing binary vs. data reclassification (2742 entries)
# 26340 INFO: Looking for ctypes DLLs
# 26454 WARNING: Library msvcrt required via ctypes not found
# 26566 WARNING: Library user32 required via ctypes not found
# 26670 WARNING: Library msvcrt required via ctypes not found
# 26723 INFO: Analyzing run-time hooks ...
# 26738 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26741 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26742 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26743 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 26744 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26748 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26839 INFO: Looking for dynamic libraries
# 30344 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.3/warn-pccloner_applinux_0.1.3.txt
# 30453 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.3/xref-pccloner_applinux_0.1.3.html
# 30548 INFO: checking PYZ
# 30548 INFO: Building PYZ because PYZ-00.toc is non existent
# 30549 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.3/PYZ-00.pyz
# 31763 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.3/PYZ-00.pyz completed successfully.
# 31911 INFO: checking PKG
# 31911 INFO: Building PKG because PKG-00.toc is non existent
# 31911 INFO: Building PKG (CArchive) pccloner_applinux_0.1.3.pkg
# 50580 INFO: Building PKG (CArchive) pccloner_applinux_0.1.3.pkg completed successfully.
# 50632 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 50632 INFO: checking EXE
# 50632 INFO: Building EXE because EXE-00.toc is non existent
# 50632 INFO: Building EXE from EXE-00.toc
# 50632 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccloner_applinux_0.1.3
# 50632 INFO: Appending PKG archive to custom ELF section in EXE
# 50759 INFO: Building EXE from EXE-00.toc completed successfully.
#
# 287 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 287 INFO: Python: 3.10.0 (conda)
# 293 INFO: Platform: Linux-5.15.0-122-generic-x86_64-with-glibc2.31
# 293 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 294 INFO: wrote /home/ezamorag/GitHub/pccloner/pccollector_applinux_0.1.3.spec
# 295 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 446 INFO: checking Analysis
# 446 INFO: Building Analysis because Analysis-00.toc is non existent
# 446 INFO: Running Analysis Analysis-00.toc
# 446 INFO: Target bytecode optimization level: 0
# 447 INFO: Initializing module dependency graph...
# 447 INFO: Caching module graph hooks...
# 456 INFO: Analyzing base_library.zip ...
# 1262 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1468 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2517 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3290 INFO: Caching module dependency graph...
# 3372 INFO: Looking for Python shared library...
# 3388 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3388 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/pccollector.py
# 3428 INFO: Processing standard module hook 'hook-pynput.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 3836 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 3954 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4039 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4090 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4144 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4550 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4567 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 4825 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5488 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5581 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5682 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6133 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 6892 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 6892 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 7609 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 7615 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7636 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7786 INFO: Processing standard module hook 'hook-Xlib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 8383 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 9490 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 9595 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 11958 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12751 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 13912 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 14029 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 15831 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 16575 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 16842 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 17840 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 18444 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19229 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 19235 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19616 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 20352 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21216 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21572 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21746 INFO: Processing module hooks (post-graph stage)...
# 22236 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22261 WARNING: Hidden import "jinja2" not found!
# 22572 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22573 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 24153 INFO: Performing binary vs. data reclassification (2742 entries)
# 24193 INFO: Looking for ctypes DLLs
# 24261 WARNING: Library msvcrt required via ctypes not found
# 24361 WARNING: Library user32 required via ctypes not found
# 24468 WARNING: Library msvcrt required via ctypes not found
# 24523 INFO: Analyzing run-time hooks ...
# 24538 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 24540 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 24541 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 24542 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 24543 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 24547 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 24639 INFO: Looking for dynamic libraries
# 27972 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.3/warn-pccollector_applinux_0.1.3.txt
# 28081 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.3/xref-pccollector_applinux_0.1.3.html
# 28171 INFO: checking PYZ
# 28171 INFO: Building PYZ because PYZ-00.toc is non existent
# 28171 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.3/PYZ-00.pyz
# 29417 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.3/PYZ-00.pyz completed successfully.
# 29521 INFO: checking PKG
# 29521 INFO: Building PKG because PKG-00.toc is non existent
# 29521 INFO: Building PKG (CArchive) pccollector_applinux_0.1.3.pkg
# 48022 INFO: Building PKG (CArchive) pccollector_applinux_0.1.3.pkg completed successfully.
# 48074 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 48074 INFO: checking EXE
# 48074 INFO: Building EXE because EXE-00.toc is non existent
# 48074 INFO: Building EXE from EXE-00.toc
# 48074 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccollector_applinux_0.1.3
# 48074 INFO: Appending PKG archive to custom ELF section in EXE
# 48211 INFO: Building EXE from EXE-00.toc completed successfully.

# %% [markdown]
# ### Routine for producing only the ubuntu app

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
print(f'Installing the latest pccloner version {getversion()} ...')
uninstallingpccloner()
run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py -n pccloner_applinux_' + getversion())
# Out:
# Installing the latest pccloner version 0.1.2 ...
# Found existing installation: pccloner 0.1.2
# Uninstalling pccloner-0.1.2:
#   Would remove:
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner-0.1.2.dist-info/*
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner/*
# Proceed (Y/n)?   Successfully uninstalled pccloner-0.1.2
#
# Collecting pccloner==0.1.2
#   Using cached pccloner-0.1.2-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: pynput>=1.7.6 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.2) (1.7.7)
# Requirement already satisfied: pyautogui>=0.9.54 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.2) (0.9.54)
# Requirement already satisfied: keyboard>=0.13.5 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.2) (0.13.5)
# Requirement already satisfied: pandas>=2.1.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pccloner==0.1.2) (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.2) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.2) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pandas>=2.1.4->pccloner==0.1.2) (2024.1)
# Requirement already satisfied: pymsgbox in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (0.0.9)
# Requirement already satisfied: mouseinfo in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (0.1.3)
# Requirement already satisfied: python3-Xlib in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyautogui>=0.9.54->pccloner==0.1.2) (0.15)
# Requirement already satisfied: six in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.2) (1.16.0)
# Requirement already satisfied: evdev>=1.3 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.2) (1.7.1)
# Requirement already satisfied: python-xlib>=0.17 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pynput>=1.7.6->pccloner==0.1.2) (0.33)
# Requirement already satisfied: pyrect in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pygetwindow>=0.0.5->pyautogui>=0.9.54->pccloner==0.1.2) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from pyscreeze>=0.1.21->pyautogui>=0.9.54->pccloner==0.1.2) (10.4.0)
# Requirement already satisfied: pyperclip in /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages (from mouseinfo->pyautogui>=0.9.54->pccloner==0.1.2) (1.9.0)
# Using cached pccloner-0.1.2-py3-none-any.whl (19 kB)
# Installing collected packages: pccloner
# Successfully installed pccloner-0.1.2
#
# Generating executable for ubuntu ...
# 310 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 310 INFO: Python: 3.10.0 (conda)
# 323 INFO: Platform: Linux-5.15.0-119-generic-x86_64-with-glibc2.31
# 323 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 323 INFO: wrote /home/ezamorag/GitHub/pccloner/pccloner_applinux_0.1.2.spec
# 324 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 496 INFO: checking Analysis
# 542 INFO: Building because /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner/pctask_pr.py changed
# 543 INFO: Running Analysis Analysis-00.toc
# 543 INFO: Target bytecode optimization level: 0
# 543 INFO: Initializing module dependency graph...
# 543 INFO: Caching module graph hooks...
# 550 INFO: Analyzing base_library.zip ...
# 1302 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1490 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2757 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3496 INFO: Caching module dependency graph...
# 3559 INFO: Looking for Python shared library...
# 3577 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3578 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/testing.py
# 3610 INFO: Processing standard module hook 'hook-pynput.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 4098 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 4226 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4313 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4346 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4403 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4813 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4830 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 5104 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5767 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5928 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5974 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6536 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 7374 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 7375 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 8085 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 8092 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 8114 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 8292 INFO: Processing standard module hook 'hook-Xlib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 8808 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 9903 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 10012 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12478 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13397 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 14695 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 15042 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 16985 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 17797 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18102 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18999 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 19588 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 20628 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 20634 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 20830 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 21549 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22471 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22896 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23086 INFO: Processing module hooks (post-graph stage)...
# 23564 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23590 WARNING: Hidden import "jinja2" not found!
# 23918 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23918 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 25520 INFO: Performing binary vs. data reclassification (2742 entries)
# 25563 INFO: Looking for ctypes DLLs
# 25661 WARNING: Library msvcrt required via ctypes not found
# 25765 WARNING: Library user32 required via ctypes not found
# 25865 WARNING: Library msvcrt required via ctypes not found
# 25926 INFO: Analyzing run-time hooks ...
# 25939 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 25942 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 25945 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 25947 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 25948 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 25953 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26055 INFO: Looking for dynamic libraries
# 29136 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.2/warn-pccloner_applinux_0.1.2.txt
# 29244 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.2/xref-pccloner_applinux_0.1.2.html
# 29348 INFO: checking PYZ
# 29366 INFO: Building because /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner/__init__.py changed
# 29366 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.2/PYZ-00.pyz
# 30617 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.2/PYZ-00.pyz completed successfully.
# 30780 INFO: checking PKG
# 30803 INFO: Building because toc changed
# 30803 INFO: Building PKG (CArchive) pccloner_applinux_0.1.2.pkg
# 49824 INFO: Building PKG (CArchive) pccloner_applinux_0.1.2.pkg completed successfully.
# 49888 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 49888 INFO: checking EXE
# 49913 INFO: Rebuilding EXE-00.toc because pccloner_applinux_0.1.2 missing
# 49913 INFO: Building EXE from EXE-00.toc
# 49913 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccloner_applinux_0.1.2
# 49913 INFO: Appending PKG archive to custom ELF section in EXE
# 50024 INFO: Building EXE from EXE-00.toc completed successfully.
