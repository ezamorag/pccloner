# %%
import os, re
import subprocess

def run_command(command):
    """Runs a shell command and prints the output."""
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    output, error = process.communicate()
    if output:
        print(output.decode())
    if error:
        print(error.decode())

def getversion():
    with open("setup.py", "r") as f:
        content = f.read()
    match = re.search(r"version='([^']+)'", content)
    if match:
        version = match.group(1)
    else:
        print("Version not found.")
    return version 

def uninstallingpccloner():
    # Run the command, sending 'y\n' (yes + newline) as input
    process = subprocess.Popen("pip uninstall pccloner", shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    output, error = process.communicate(input='y\n') 
    # Print the output and any errors
    print(output)
    if error:
        print(error)
        
# Make sure that yuo have the environment below: 
# conda create --name x python==3.10
# conda activate x
# pip install pyinstaller
# pip install --upgrade build

# %% [markdown]
# ### Routine for producing the pip package and the ubuntu app

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
print('Building ...')
run_command('python -m build')
print('Downloading PIP package ...')
run_command('twine upload --repository pypi dist/*')

print(f'Installing the latest pccloner version {getversion()} ...')
uninstallingpccloner()
run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py --collect-all pccloner -n pccloner_applinux_' + getversion())
run_command('pyinstaller -F scripts/pccollector.py --collect-all pccloner -n pccollector_applinux_' + getversion())
# Out:
# Building ...
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for sdist...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# running check
# creating pccloner-0.1.8
# creating pccloner-0.1.8/src/pccloner
# creating pccloner-0.1.8/src/pccloner.egg-info
# copying files to pccloner-0.1.8...
# copying LICENSE -> pccloner-0.1.8
# copying README.md -> pccloner-0.1.8
# copying pyproject.toml -> pccloner-0.1.8
# copying setup.py -> pccloner-0.1.8
# copying src/pccloner/__init__.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/pcdata.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/pctask_pr.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/pctask_press.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/ubuntu.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/utils.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner/win11.py -> pccloner-0.1.8/src/pccloner
# copying src/pccloner.egg-info/PKG-INFO -> pccloner-0.1.8/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.8/src/pccloner.egg-info
# copying src/pccloner.egg-info/dependency_links.txt -> pccloner-0.1.8/src/pccloner.egg-info
# copying src/pccloner.egg-info/requires.txt -> pccloner-0.1.8/src/pccloner.egg-info
# copying src/pccloner.egg-info/top_level.txt -> pccloner-0.1.8/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.8/src/pccloner.egg-info
# Writing pccloner-0.1.8/setup.cfg
# Creating tar archive
# removing 'pccloner-0.1.8' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for wheel...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/pccloner
# copying src/pccloner/__init__.py -> build/lib/pccloner
# copying src/pccloner/pcdata.py -> build/lib/pccloner
# copying src/pccloner/pctask_press.py -> build/lib/pccloner
# copying src/pccloner/pctask_pr.py -> build/lib/pccloner
# copying src/pccloner/win11.py -> build/lib/pccloner
# copying src/pccloner/ubuntu.py -> build/lib/pccloner
# copying src/pccloner/utils.py -> build/lib/pccloner
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/pccloner
# copying build/lib/pccloner/__init__.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/ubuntu.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/win11.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_pr.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_press.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pcdata.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/utils.py -> build/bdist.linux-x86_64/wheel/./pccloner
# running install_egg_info
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# Copying src/pccloner.egg-info to build/bdist.linux-x86_64/wheel/./pccloner-0.1.8-py3.10.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/pccloner-0.1.8.dist-info/WHEEL
# creating '/home/ezamorag/GitHub/pccloner/dist/.tmp-lp8xq3a1/pccloner-0.1.8-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'pccloner/__init__.py'
# adding 'pccloner/pcdata.py'
# adding 'pccloner/pctask_pr.py'
# adding 'pccloner/pctask_press.py'
# adding 'pccloner/ubuntu.py'
# adding 'pccloner/utils.py'
# adding 'pccloner/win11.py'
# adding 'pccloner-0.1.8.dist-info/LICENSE'
# adding 'pccloner-0.1.8.dist-info/METADATA'
# adding 'pccloner-0.1.8.dist-info/WHEEL'
# adding 'pccloner-0.1.8.dist-info/top_level.txt'
# adding 'pccloner-0.1.8.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built pccloner-0.1.8.tar.gz and pccloner-0.1.8-py3-none-any.whl
#
# Downloading PIP package ...
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading pccloner-0.1.8-py3-none-any.whl
# 100%|██████████| 29.4k/29.4k [00:03<00:00, 9.87kB/s]
# Uploading pccloner-0.1.8.tar.gz
# 100%|██████████| 27.1k/27.1k [00:00<00:00, 37.2kB/s]
#
# View at:
# https://pypi.org/project/pccloner/0.1.8/
#
# Installing the latest pccloner version 0.1.8 ...
#
# WARNING: Skipping pccloner as it is not installed.
#
# ERROR: Could not find a version that satisfies the requirement pccloner==0.1.8 (from versions: 0.0.8, 0.0.8.1, 0.0.9, 0.0.10, 0.0.11, 0.0.11.1, 0.0.12, 0.0.13, 0.0.14, 0.0.15, 0.0.16, 0.0.17, 0.0.18, 0.0.19, 0.0.20, 0.0.21, 0.0.23, 0.0.24, 0.0.25, 0.0.26, 0.0.27, 0.1.0, 0.1.1, 0.1.2, 0.1.3, 0.1.4, 0.1.5, 0.1.5.1, 0.1.6, 0.1.7)
# ERROR: No matching distribution found for pccloner==0.1.8
#
# Generating executable for ubuntu ...
# 280 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 280 INFO: Python: 3.10.0 (conda)
# 282 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 282 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 283 INFO: wrote /home/ezamorag/GitHub/pccloner/pccloner_applinux_0.1.8.spec
# 285 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 439 INFO: checking Analysis
# 439 INFO: Building Analysis because Analysis-00.toc is non existent
# 439 INFO: Running Analysis Analysis-00.toc
# 439 INFO: Target bytecode optimization level: 0
# 439 INFO: Initializing module dependency graph...
# 440 INFO: Caching module graph hooks...
# 450 INFO: Analyzing base_library.zip ...
# 1315 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1378 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2484 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3360 INFO: Caching module dependency graph...
# 3422 INFO: Looking for Python shared library...
# 3438 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3438 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/testing.py
# 3447 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4443 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4456 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4471 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4488 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 5453 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5561 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5605 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6139 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 7055 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7156 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7157 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 9847 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 10824 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 11679 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 12109 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12162 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12264 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12316 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13088 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 13093 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13116 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13147 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 14628 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 15120 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 15886 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 16175 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 17019 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 17613 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18575 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 18580 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18768 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 19485 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20531 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20764 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20928 INFO: Processing module hooks (post-graph stage)...
# 21127 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21152 WARNING: Hidden import "jinja2" not found!
# 21445 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21446 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 22961 INFO: Performing binary vs. data reclassification (2742 entries)
# 23003 INFO: Looking for ctypes DLLs
# 23121 WARNING: Library user32 required via ctypes not found
# 23217 WARNING: Library msvcrt required via ctypes not found
# 23232 INFO: Analyzing run-time hooks ...
# 23295 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23296 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23297 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23298 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 23299 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23301 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23388 INFO: Looking for dynamic libraries
# 26803 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.8/warn-pccloner_applinux_0.1.8.txt
# 26901 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.8/xref-pccloner_applinux_0.1.8.html
# 26986 INFO: checking PYZ
# 26986 INFO: Building PYZ because PYZ-00.toc is non existent
# 26986 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.8/PYZ-00.pyz
# 28146 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.8/PYZ-00.pyz completed successfully.
# 28262 INFO: checking PKG
# 28262 INFO: Building PKG because PKG-00.toc is non existent
# 28262 INFO: Building PKG (CArchive) pccloner_applinux_0.1.8.pkg
# 46721 INFO: Building PKG (CArchive) pccloner_applinux_0.1.8.pkg completed successfully.
# 46772 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 46772 INFO: checking EXE
# 46772 INFO: Building EXE because EXE-00.toc is non existent
# 46772 INFO: Building EXE from EXE-00.toc
# 46772 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccloner_applinux_0.1.8
# 46772 INFO: Appending PKG archive to custom ELF section in EXE
# 46882 INFO: Building EXE from EXE-00.toc completed successfully.
#
# 298 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 298 INFO: Python: 3.10.0 (conda)
# 308 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 308 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 309 INFO: wrote /home/ezamorag/GitHub/pccloner/pccollector_applinux_0.1.8.spec
# 312 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 479 INFO: checking Analysis
# 480 INFO: Building Analysis because Analysis-00.toc is non existent
# 480 INFO: Running Analysis Analysis-00.toc
# 480 INFO: Target bytecode optimization level: 0
# 480 INFO: Initializing module dependency graph...
# 481 INFO: Caching module graph hooks...
# 500 INFO: Analyzing base_library.zip ...
# 1254 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1383 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2537 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3356 INFO: Caching module dependency graph...
# 3418 INFO: Looking for Python shared library...
# 3432 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3432 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/pccollector.py
# 3433 INFO: Processing module hooks (post-graph stage)...
# 3440 INFO: Performing binary vs. data reclassification (2 entries)
# 3445 INFO: Looking for ctypes DLLs
# 3451 INFO: Analyzing run-time hooks ...
# 3454 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 3463 INFO: Looking for dynamic libraries
# 4282 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.8/warn-pccollector_applinux_0.1.8.txt
# 4297 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.8/xref-pccollector_applinux_0.1.8.html
# 4306 INFO: checking PYZ
# 4306 INFO: Building PYZ because PYZ-00.toc is non existent
# 4306 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.8/PYZ-00.pyz
# 4429 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.8/PYZ-00.pyz completed successfully.
# 4446 INFO: checking PKG
# 4446 INFO: Building PKG because PKG-00.toc is non existent
# 4446 INFO: Building PKG (CArchive) pccollector_applinux_0.1.8.pkg
# 10248 INFO: Building PKG (CArchive) pccollector_applinux_0.1.8.pkg completed successfully.
# 10250 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 10250 INFO: checking EXE
# 10250 INFO: Building EXE because EXE-00.toc is non existent
# 10250 INFO: Building EXE from EXE-00.toc
# 10250 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccollector_applinux_0.1.8
# 10250 INFO: Appending PKG archive to custom ELF section in EXE
# 10283 INFO: Building EXE from EXE-00.toc completed successfully.

# %% [markdown]
# ### Routine for producing only the ubuntu apps

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
#print(f'Installing the latest pccloner version {getversion()} ...')
#uninstallingpccloner()
#run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py --collect-all pccloner -n pccloner_applinux_' + getversion())
run_command('pyinstaller -F scripts/pccollector.py --collect-all pccloner -n pccollector_applinux_' + getversion())
# Out:
# Generating executable for ubuntu ...
