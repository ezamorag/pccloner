# %%
import os, re
import subprocess

def run_command(command):
    """Runs a shell command and prints the output."""
    process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    output, error = process.communicate()
    if output:
        print(output.decode())
    if error:
        print(error.decode())

def getversion():
    with open("setup.py", "r") as f:
        content = f.read()
    match = re.search(r"version='([^']+)'", content)
    if match:
        version = match.group(1)
    else:
        print("Version not found.")
    return version 

def uninstallingpccloner():
    # Run the command, sending 'y\n' (yes + newline) as input
    process = subprocess.Popen("pip uninstall pccloner", shell=True, stdin=subprocess.PIPE, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    output, error = process.communicate(input='y\n') 
    # Print the output and any errors
    print(output)
    if error:
        print(error)
        
# Make sure that yuo have the environment below: 
# conda create --name x python==3.10
# conda activate x
# pip install pyinstaller
# pip install --upgrade build

# %% [markdown]
# ### Routine for producing the pip package and the ubuntu app

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
print('Building ...')
run_command('python -m build')
print('Downloading PIP package ...')
run_command('twine upload --repository pypi dist/*')

print(f'Installing the latest pccloner version {getversion()} ...')
uninstallingpccloner()
run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py --hidden-import pccloner -n pccloner_applinux_' + getversion())
run_command('pyinstaller -F scripts/pccollector.py --hidden-import pccloner -n pccollector_applinux_' + getversion())
# Out:
# Building ...
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for sdist...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# running check
# creating pccloner-0.1.6
# creating pccloner-0.1.6/src/pccloner
# creating pccloner-0.1.6/src/pccloner.egg-info
# copying files to pccloner-0.1.6...
# copying LICENSE -> pccloner-0.1.6
# copying README.md -> pccloner-0.1.6
# copying pyproject.toml -> pccloner-0.1.6
# copying setup.py -> pccloner-0.1.6
# copying src/pccloner/__init__.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner/pcdata.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner/pctask_pr.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner/pctask_press.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner/ubuntu.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner/win11.py -> pccloner-0.1.6/src/pccloner
# copying src/pccloner.egg-info/PKG-INFO -> pccloner-0.1.6/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.6/src/pccloner.egg-info
# copying src/pccloner.egg-info/dependency_links.txt -> pccloner-0.1.6/src/pccloner.egg-info
# copying src/pccloner.egg-info/requires.txt -> pccloner-0.1.6/src/pccloner.egg-info
# copying src/pccloner.egg-info/top_level.txt -> pccloner-0.1.6/src/pccloner.egg-info
# copying src/pccloner.egg-info/SOURCES.txt -> pccloner-0.1.6/src/pccloner.egg-info
# Writing pccloner-0.1.6/setup.cfg
# Creating tar archive
# removing 'pccloner-0.1.6' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools
# * Getting build dependencies for wheel...
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/pccloner
# copying src/pccloner/__init__.py -> build/lib/pccloner
# copying src/pccloner/pcdata.py -> build/lib/pccloner
# copying src/pccloner/pctask_press.py -> build/lib/pccloner
# copying src/pccloner/pctask_pr.py -> build/lib/pccloner
# copying src/pccloner/win11.py -> build/lib/pccloner
# copying src/pccloner/ubuntu.py -> build/lib/pccloner
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/pccloner
# copying build/lib/pccloner/__init__.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/ubuntu.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/win11.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_pr.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pctask_press.py -> build/bdist.linux-x86_64/wheel/./pccloner
# copying build/lib/pccloner/pcdata.py -> build/bdist.linux-x86_64/wheel/./pccloner
# running install_egg_info
# running egg_info
# writing src/pccloner.egg-info/PKG-INFO
# writing dependency_links to src/pccloner.egg-info/dependency_links.txt
# writing requirements to src/pccloner.egg-info/requires.txt
# writing top-level names to src/pccloner.egg-info/top_level.txt
# reading manifest file 'src/pccloner.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'src/pccloner.egg-info/SOURCES.txt'
# Copying src/pccloner.egg-info to build/bdist.linux-x86_64/wheel/./pccloner-0.1.6-py3.10.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/pccloner-0.1.6.dist-info/WHEEL
# creating '/home/ezamorag/GitHub/pccloner/dist/.tmp-54eytd2y/pccloner-0.1.6-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'pccloner/__init__.py'
# adding 'pccloner/pcdata.py'
# adding 'pccloner/pctask_pr.py'
# adding 'pccloner/pctask_press.py'
# adding 'pccloner/ubuntu.py'
# adding 'pccloner/win11.py'
# adding 'pccloner-0.1.6.dist-info/LICENSE'
# adding 'pccloner-0.1.6.dist-info/METADATA'
# adding 'pccloner-0.1.6.dist-info/WHEEL'
# adding 'pccloner-0.1.6.dist-info/top_level.txt'
# adding 'pccloner-0.1.6.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built pccloner-0.1.6.tar.gz and pccloner-0.1.6-py3-none-any.whl
#
# Downloading PIP package ...
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading pccloner-0.1.6-py3-none-any.whl
# 100%|██████████| 28.7k/28.7k [00:01<00:00, 24.6kB/s]
# Uploading pccloner-0.1.6.tar.gz
# 100%|██████████| 26.6k/26.6k [00:01<00:00, 18.9kB/s]
#
# View at:
# https://pypi.org/project/pccloner/0.1.6/
#
# Installing the latest pccloner version 0.1.6 ...
# Found existing installation: pccloner 0.1.5.1
# Uninstalling pccloner-0.1.5.1:
#   Would remove:
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner-0.1.5.1.dist-info/*
#     /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/pccloner/*
# Proceed (Y/n)?   Successfully uninstalled pccloner-0.1.5.1
#
# ERROR: Could not find a version that satisfies the requirement pccloner==0.1.6 (from versions: 0.0.8, 0.0.8.1, 0.0.9, 0.0.10, 0.0.11, 0.0.11.1, 0.0.12, 0.0.13, 0.0.14, 0.0.15, 0.0.16, 0.0.17, 0.0.18, 0.0.19, 0.0.20, 0.0.21, 0.0.23, 0.0.24, 0.0.25, 0.0.26, 0.0.27, 0.1.0, 0.1.1, 0.1.2, 0.1.3, 0.1.4, 0.1.5, 0.1.5.1)
# ERROR: No matching distribution found for pccloner==0.1.6
#
# Generating executable for ubuntu ...
# 279 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 279 INFO: Python: 3.10.0 (conda)
# 283 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 283 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 284 INFO: wrote /home/ezamorag/GitHub/pccloner/pccloner_applinux_0.1.6.spec
# 286 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 439 INFO: checking Analysis
# 439 INFO: Building Analysis because Analysis-00.toc is non existent
# 440 INFO: Running Analysis Analysis-00.toc
# 440 INFO: Target bytecode optimization level: 0
# 440 INFO: Initializing module dependency graph...
# 441 INFO: Caching module graph hooks...
# 459 INFO: Analyzing base_library.zip ...
# 1273 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1322 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2506 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3395 INFO: Caching module dependency graph...
# 3463 INFO: Looking for Python shared library...
# 3478 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3478 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/testing.py
# 3488 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4496 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4510 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4525 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4550 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 5455 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5561 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5658 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6150 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 6965 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7095 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7096 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 9895 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 10689 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 11540 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 11999 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12052 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12163 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12415 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13004 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 13010 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13032 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13063 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 14760 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 15076 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 15850 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 16149 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 16956 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 17725 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18550 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 18555 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18940 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 19683 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20501 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20829 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 20995 INFO: Processing module hooks (post-graph stage)...
# 21147 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21171 WARNING: Hidden import "jinja2" not found!
# 21457 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21458 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 22979 INFO: Performing binary vs. data reclassification (2742 entries)
# 23019 INFO: Looking for ctypes DLLs
# 23105 WARNING: Library user32 required via ctypes not found
# 23201 WARNING: Library msvcrt required via ctypes not found
# 23216 INFO: Analyzing run-time hooks ...
# 23234 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23235 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23237 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23238 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 23239 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23242 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 23331 INFO: Looking for dynamic libraries
# 26719 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.6/warn-pccloner_applinux_0.1.6.txt
# 26822 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.6/xref-pccloner_applinux_0.1.6.html
# 26914 INFO: checking PYZ
# 26914 INFO: Building PYZ because PYZ-00.toc is non existent
# 26914 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.6/PYZ-00.pyz
# 28073 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccloner_applinux_0.1.6/PYZ-00.pyz completed successfully.
# 28166 INFO: checking PKG
# 28166 INFO: Building PKG because PKG-00.toc is non existent
# 28166 INFO: Building PKG (CArchive) pccloner_applinux_0.1.6.pkg
# 46452 INFO: Building PKG (CArchive) pccloner_applinux_0.1.6.pkg completed successfully.
# 46503 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 46503 INFO: checking EXE
# 46503 INFO: Building EXE because EXE-00.toc is non existent
# 46503 INFO: Building EXE from EXE-00.toc
# 46503 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccloner_applinux_0.1.6
# 46503 INFO: Appending PKG archive to custom ELF section in EXE
# 46643 INFO: Building EXE from EXE-00.toc completed successfully.
#
# 289 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 289 INFO: Python: 3.10.0 (conda)
# 294 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 294 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 295 INFO: wrote /home/ezamorag/GitHub/pccloner/pccollector_applinux_0.1.6.spec
# 303 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 481 INFO: checking Analysis
# 481 INFO: Building Analysis because Analysis-00.toc is non existent
# 481 INFO: Running Analysis Analysis-00.toc
# 481 INFO: Target bytecode optimization level: 0
# 481 INFO: Initializing module dependency graph...
# 482 INFO: Caching module graph hooks...
# 491 INFO: Analyzing base_library.zip ...
# 1340 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1416 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2474 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3344 INFO: Caching module dependency graph...
# 3407 INFO: Looking for Python shared library...
# 3421 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3421 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/pccollector.py
# 3423 INFO: Processing module hooks (post-graph stage)...
# 3438 INFO: Performing binary vs. data reclassification (2 entries)
# 3444 INFO: Looking for ctypes DLLs
# 3448 INFO: Analyzing run-time hooks ...
# 3451 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 3460 INFO: Looking for dynamic libraries
# 4291 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/warn-pccollector_applinux_0.1.6.txt
# 4307 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/xref-pccollector_applinux_0.1.6.html
# 4317 INFO: checking PYZ
# 4318 INFO: Building PYZ because PYZ-00.toc is non existent
# 4318 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/PYZ-00.pyz
# 4440 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/PYZ-00.pyz completed successfully.
# 4461 INFO: checking PKG
# 4461 INFO: Building PKG because PKG-00.toc is non existent
# 4461 INFO: Building PKG (CArchive) pccollector_applinux_0.1.6.pkg
# 10151 INFO: Building PKG (CArchive) pccollector_applinux_0.1.6.pkg completed successfully.
# 10152 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 10152 INFO: checking EXE
# 10152 INFO: Building EXE because EXE-00.toc is non existent
# 10152 INFO: Building EXE from EXE-00.toc
# 10152 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccollector_applinux_0.1.6
# 10153 INFO: Appending PKG archive to custom ELF section in EXE
# 10180 INFO: Building EXE from EXE-00.toc completed successfully.

# %% [markdown]
# ### Routine for producing only the ubuntu apps

# %%
base_dir = '/home/ezamorag/GitHub/pccloner'
os.chdir(base_dir)  # Replace with your actual path
#print(f'Installing the latest pccloner version {getversion()} ...')
#uninstallingpccloner()
#run_command('pip install pccloner==' + getversion())
print('Generating executable for ubuntu ...')
run_command('pyinstaller -F scripts/testing.py --hidden-import pccloner -n pccloner_applinux_' + getversion())
run_command('pyinstaller -F scripts/pccollector.py --hidden-import pccloner -n pccollector_applinux_' + getversion())
# Out:
# Generating executable for ubuntu ...
# 279 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 280 INFO: Python: 3.10.0 (conda)
# 284 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 284 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 284 INFO: wrote /home/ezamorag/GitHub/pccloner/pccloner_applinux_0.1.6.spec
# 286 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 433 INFO: checking Analysis
# 496 INFO: checking PYZ
# 568 INFO: checking PKG
# 611 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 611 INFO: checking EXE
# 630 INFO: Rebuilding EXE-00.toc because pccloner_applinux_0.1.6 missing
# 630 INFO: Building EXE from EXE-00.toc
# 630 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccloner_applinux_0.1.6
# 630 INFO: Appending PKG archive to custom ELF section in EXE
# 788 INFO: Building EXE from EXE-00.toc completed successfully.
#
# 290 INFO: PyInstaller: 6.10.0, contrib hooks: 2024.8
# 290 INFO: Python: 3.10.0 (conda)
# 293 INFO: Platform: Linux-5.15.0-124-generic-x86_64-with-glibc2.31
# 293 INFO: Python environment: /home/ezamorag/miniconda3/envs/x
# 294 INFO: wrote /home/ezamorag/GitHub/pccloner/pccollector_applinux_0.1.6.spec
# 295 INFO: Module search paths (PYTHONPATH):
# ['/home/ezamorag/miniconda3/envs/x/lib/python310.zip',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/lib-dynload',
#  '/home/ezamorag/.local/lib/python3.10/site-packages',
#  '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages',
#  '/home/ezamorag/GitHub/pccloner/scripts']
# 474 INFO: checking Analysis
# 477 INFO: Building because hiddenimports changed
# 478 INFO: Running Analysis Analysis-00.toc
# 478 INFO: Target bytecode optimization level: 0
# 478 INFO: Initializing module dependency graph...
# 479 INFO: Caching module graph hooks...
# 496 INFO: Analyzing base_library.zip ...
# 1316 INFO: Processing standard module hook 'hook-heapq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 1368 INFO: Processing standard module hook 'hook-encodings.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 2576 INFO: Processing standard module hook 'hook-pickle.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 3405 INFO: Caching module dependency graph...
# 3468 INFO: Looking for Python shared library...
# 3486 INFO: Using Python shared library: /home/ezamorag/miniconda3/envs/x/lib/libpython3.10.so.1.0
# 3486 INFO: Analyzing /home/ezamorag/GitHub/pccloner/scripts/pccollector.py
# 3519 INFO: Processing standard module hook 'hook-pynput.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 3953 INFO: Processing pre-safe-import-module hook 'hook-six.moves.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 4024 INFO: Processing standard module hook 'hook-platform.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4131 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4164 INFO: Processing standard module hook 'hook-PIL.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4221 INFO: Processing standard module hook 'hook-PIL.Image.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 4678 INFO: Processing standard module hook 'hook-numpy.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/numpy/_pyinstaller'
# 4695 WARNING: Conda distribution 'numpy', dependency of 'numpy', was not found. If you installed this distribution with pip then you may ignore this warning.
# 4971 INFO: Processing standard module hook 'hook-sysconfig.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5612 INFO: Processing standard module hook 'hook-difflib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5763 INFO: Processing standard module hook 'hook-multiprocessing.util.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 5809 INFO: Processing standard module hook 'hook-xml.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 6347 INFO: Processing standard module hook 'hook-psutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 7204 INFO: Processing pre-safe-import-module hook 'hook-typing_extensions.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 7205 INFO: SetuptoolsInfo: initializing cached setuptools info...
# 7931 INFO: Processing pre-safe-import-module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 7937 INFO: Processing standard module hook 'hook-packaging.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 7959 INFO: Processing standard module hook 'hook-PIL.ImageFilter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 8132 INFO: Processing standard module hook 'hook-Xlib.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 8678 INFO: Processing standard module hook 'hook-pandas.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 9726 INFO: Processing standard module hook 'hook-pytz.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 9867 INFO: Processing standard module hook 'hook-pkg_resources.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 12100 INFO: Processing standard module hook 'hook-pandas.io.formats.style.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 13045 INFO: Processing standard module hook 'hook-IPython.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 14266 INFO: Processing standard module hook 'hook-xml.dom.domreg.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 14395 INFO: Processing standard module hook 'hook-pygments.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 16308 INFO: Processing standard module hook 'hook-wcwidth.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 17126 INFO: Processing standard module hook 'hook-jedi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 17418 INFO: Processing standard module hook 'hook-parso.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 18255 INFO: Processing standard module hook 'hook-sqlite3.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 18827 INFO: Processing standard module hook 'hook-zmq.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 19783 INFO: Processing pre-safe-import-module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 19787 INFO: Processing standard module hook 'hook-platformdirs.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 20177 INFO: Processing pre-safe-import-module hook 'hook-gi.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 20876 INFO: Processing standard module hook 'hook-pandas.plotting.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 21723 INFO: Processing standard module hook 'hook-pandas.io.clipboard.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22092 INFO: Processing standard module hook 'hook-xml.etree.cElementTree.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22364 INFO: Processing pre-safe-import-module hook 'hook-importlib_metadata.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 22378 INFO: Processing standard module hook 'hook-importlib_metadata.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 22379 INFO: Processing pre-safe-import-module hook 'hook-zipp.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/pre_safe_import_module'
# 22440 INFO: Processing standard module hook 'hook-Cryptodome.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/stdhooks'
# 22960 INFO: Processing module hooks (post-graph stage)...
# 23505 INFO: Processing standard module hook 'hook-PIL.SpiderImagePlugin.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23530 WARNING: Hidden import "jinja2" not found!
# 23855 INFO: Processing standard module hook 'hook-_tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks'
# 23856 INFO: TclTkInfo: initializing cached Tcl/Tk info...
# 25384 INFO: Performing binary vs. data reclassification (2790 entries)
# 25661 INFO: Looking for ctypes DLLs
# 25785 WARNING: Library msvcrt required via ctypes not found
# 25902 WARNING: Library user32 required via ctypes not found
# 26009 WARNING: Library msvcrt required via ctypes not found
# 26103 INFO: Analyzing run-time hooks ...
# 26118 INFO: Including run-time hook 'pyi_rth_inspect.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26120 INFO: Including run-time hook 'pyi_rth_multiprocessing.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26121 INFO: Including run-time hook 'pyi_rth_pkgutil.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26122 INFO: Including run-time hook 'pyi_rth_traitlets.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/_pyinstaller_hooks_contrib/rthooks'
# 26123 INFO: Including run-time hook 'pyi_rth_pkgres.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26126 INFO: Including run-time hook 'pyi_rth__tkinter.py' from '/home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/hooks/rthooks'
# 26217 INFO: Looking for dynamic libraries
# 30558 INFO: Warnings written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/warn-pccollector_applinux_0.1.6.txt
# 30679 INFO: Graph cross-reference written to /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/xref-pccollector_applinux_0.1.6.html
# 30770 INFO: checking PYZ
# 30771 INFO: Building because toc changed
# 30771 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/PYZ-00.pyz
# 32036 INFO: Building PYZ (ZlibArchive) /home/ezamorag/GitHub/pccloner/build/pccollector_applinux_0.1.6/PYZ-00.pyz completed successfully.
# 32208 INFO: checking PKG
# 32209 INFO: Building because toc changed
# 32209 INFO: Building PKG (CArchive) pccollector_applinux_0.1.6.pkg
# 53305 INFO: Building PKG (CArchive) pccollector_applinux_0.1.6.pkg completed successfully.
# 53387 INFO: Bootloader /home/ezamorag/miniconda3/envs/x/lib/python3.10/site-packages/PyInstaller/bootloader/Linux-64bit-intel/run
# 53388 INFO: checking EXE
# 53388 INFO: Rebuilding EXE-00.toc because pccollector_applinux_0.1.6 missing
# 53388 INFO: Building EXE from EXE-00.toc
# 53388 INFO: Copying bootloader EXE to /home/ezamorag/GitHub/pccloner/dist/pccollector_applinux_0.1.6
# 53388 INFO: Appending PKG archive to custom ELF section in EXE
# 53501 INFO: Building EXE from EXE-00.toc completed successfully.
